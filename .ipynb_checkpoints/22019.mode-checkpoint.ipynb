# %%
import os
import cv2
import numpy as np

# %% [markdown]
# # étiqueter les données

# %%
import os
import cv2
import numpy as np
from shutil import copyfile


from easyocr import Reader



import pytesseract
# Fonctions de détection de plaque d'immatriculation
def order_points(pts):
    rect = np.zeros((4, 2), dtype="float32")
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]
    rect[2] = pts[np.argmax(s)]

    diff = np.diff(pts, axis=1)
    rect[1] = pts[np.argmin(diff)]
    rect[3] = pts[np.argmax(diff)]

    return rect

def four_point_transform(image, pts):
    rect = order_points(pts)
    (tl, tr, br, bl) = rect

    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return warped

def process_single_image(image_path, output_dir):
    # Charger l'image
    car = cv2.imread(image_path)
    # Convertir en niveau de gris
    gray = cv2.cvtColor(car, cv2.COLOR_BGR2GRAY)
    # Appliquer un flou gaussien
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    # Détecter les contours
    edged = cv2.Canny(blur, 50, 200)
    # Trouver les contours les plus grands
    cont, _ = cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cont = sorted(cont, key=cv2.contourArea, reverse=True)[:5]

    plate_cnt = None
    for c in cont:
        arc = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * arc, True)
        if len(approx) == 4:
            plate_cnt = approx
            break

    if plate_cnt is None:
        print(f"No license plate detected in {image_path}.")
        return None

    # Redresser la plaque d'immatriculation
    warped_plate = four_point_transform(gray, plate_cnt.reshape(4, 2))

    # Redimensionner la plaque pour améliorer la précision de l'OCR
    plate = cv2.resize(warped_plate, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    # Utiliser EasyOCR pour reconnaître les caractères de la plaque
    reader = Reader(['en'])
    detection = reader.readtext(plate)

    if len(detection) == 0:
        print(f"Unable to read license plate text in {image_path}.")
        return None

    # Extraire le texte reconnu
    text = detection[0][1]

    # Filtrer pour obtenir uniquement les lettres et les chiffres
    filtered_text = ''.join([c for c in text if c.isalnum()])

    # Nommer l'image avec le numéro de plaque d'immatriculation
    output_filename = os.path.join(output_dir, f'{filtered_text}.jpg')

    # Sauvegarder l'image annotée
    cv2.imwrite(output_filename, car)

    return output_filename

# Répertoire contenant les images de voitures
data_train_dir = "data_train"

# Créer un répertoire pour les images annotées
data_mat_train_dir = "data_mat_train"
os.makedirs(data_mat_train_dir, exist_ok=True)

# Parcourir les images dans le dossier data_train
for filename in os.listdir(data_train_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(data_train_dir, filename)
        output_filename = process_single_image(image_path, data_mat_train_dir)
        if output_filename:
            print(f"Processed: {filename} -> Saved as: {output_filename}")
        else:
            print(f"Processed: {filename} -> No license plate detected or unable to read text.")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 0001059f437adecbe8cb75d4285b1f10f9e23353.jpg -> Saved as: data_mat_train\IoYoia.jpg
# No license plate detected in data_train\0015a3765cca1cd4fe7633ec6bcfff9e31d9b308.jpg.
# Processed: 0015a3765cca1cd4fe7633ec6bcfff9e31d9b308.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# No license plate detected in data_train\00217b4be852c526be6f2b9345f79732cb3fa1e4.jpg.
# Processed: 00217b4be852c526be6f2b9345f79732cb3fa1e4.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 00238ac361d42cab40ad91d3384f3b85e06b7c83.jpg -> Saved as: data_mat_train\636AR12.jpg
# No license plate detected in data_train\00251c10774435dfab6253e76557bd1b19540e2b.png.
# Processed: 00251c10774435dfab6253e76557bd1b19540e2b.png -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_train
jpg -> No license plate detected or unable to read text.
# No license plate detected in data_train\c103ffe3a42dbeb3098c1dfa356ae65c411b851b.jpg.
# Processed: c103ffe3a42dbeb3098c1dfa356ae65c411b851b.jpg -> No license plate detected or unable to read text.
# Unable to read license plate text in data_train\c1065942ebcd8b28d58fd406aaac2573dd1b12d1.jpg.
# Processed: c1065942ebcd8b28d58fd406aaac2573dd1b12d1.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c113b737cbd8ec89a580fdfe49d307bb6ae36fec.jpg -> Saved as: data_mat_train\2316Az00.jpg
# No license plate detected in data_train\c1283676db6c99c6d7b76f9be2705e362883571d.jpg.
# Processed: c1283676db6c99c6d7b76f9be2705e362883571d.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_train\c130ac92581da895472a56d66ef7859e54c7b45f.jpg.
# Processed: c130ac92581da895472a56d66ef7859e54c7b45f.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_train\c13633f2e9b0352b4326dc359bb60a4f3ab41d53.jpg.
# Processed: c13633f2e9b0352b4326dc359bb60a4f3ab41d53.jpg -> No license plate detected or unable to read text.
# Processed: c13af47a4e97b71dc2c9d9f4f7230d5a9de4fc9c.jpg -> Saved as: data_mat_train\CY45307.jpg
# No license plate detected in data_train\c141ea17e80d027e06d69de01bed5ea8599aadd7.jpg.
# Processed: c141ea17e80d027e06d69de01bed5ea8599aadd7.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# No license plate detected in data_train\c147f7b58632883fdd7303392b108ba68743960a.jpg.
# Processed: c147f7b58632883fdd7303392b108ba68743960a.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_train\c1526886ebc4bfced6cb79a9e78600f52f2f3e94.jpg.
# Processed: c1526886ebc4bfced6cb79a9e78600f52f2f3e94.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c16471386183da4ee13b41581543c5d733d28800.jpg -> Saved as: data_mat_train\4691M0z.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c174eb67550c59a3cb0eea7a462188ef4a3e8e04.jpg -> Saved as: data_mat_train\0581BAQQ.jpg
# No license plate detected in data_train\c175a49aad3fcd2cf1f6bf5fd05ac96c5ee69d3b.jpg.
# Processed: c175a49aad3fcd2cf1f6bf5fd05ac96c5ee69d3b.jpg -> No license plate detected or unable to read text.
# Processed: c1853b40db529fb6077f4a03d1ad24968923f6bb.jpg -> Saved as: data_mat_train\72454006.jpg
# No license plate detected in data_train\c18dce1a1a4035fe6d97cca44b063af75ec577ff.jpg.
# Processed: c18dce1a1a4035fe6d97cca44b063af75ec577ff.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c1982f4b3e40b69e7ba8d5ab72f7217872bac20e.jpg -> Saved as: data_mat_train\3401AB07.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c1a06d31dffe36910ac35450c60e7e6e5f8e3f00.jpg -> Saved as: data_mat_train\0293AROO.jpg
# Processed: c1a44dad646c8ac6eb79b2af6341e672c3ef87a9.jpg -> Saved as: data_mat_train\L7254800.jpg
# No license plate detected in data_train\c1ad7cb25d8d324897ef1a1ddc9d888f6337fa52.jpg.
# Processed: c1ad7cb25d8d324897ef1a1ddc9d888f6337fa52.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: c1b1721c35882d847cc2b39bbb51884c4881f83b.jpg -> Saved as: data_mat_train\A1121AA118.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# No license plate detected in data_train\c1c86b727a8a5b3ac08863e3abef8ffefb80205f.jpg.
# Processed: c1c86b727a8a5b3ac08863e3abef8ffefb80205f.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_train\c1d411393126047e2c573e26c1ed2dd734380de7.jpg.
# Processed: c1d411393126047e2c573e26c1ed2dd734380de7.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_train\c1d485748c5a2b9cf7a6b3497e649c8aeabaf657.jpg.
# Processed: c1d485748c5a2b9cf7a6b3497e649c8aeabaf657.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_train\c1db6a7ebf1a4f01de0c31599e5cc3e0a68043c7.jpg.
# Processed: c1db6a7ebf1a4f01de0c31599e5cc3e0a68043c7.jpg -> No license plate detected or unable to read text.

# %%
import os
import cv2
import numpy as np
from shutil import copyfile
from easyocr import Reader
import pytesseract

# Fonctions de détection de plaque d'immatriculation
def order_points(pts):
    rect = np.zeros((4, 2), dtype="float32")
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]
    rect[2] = pts[np.argmax(s)]

    diff = np.diff(pts, axis=1)
    rect[1] = pts[np.argmin(diff)]
    rect[3] = pts[np.argmax(diff)]

    return rect

def four_point_transform(image, pts):
    rect = order_points(pts)
    (tl, tr, br, bl) = rect

    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return warped

def process_single_image(image_path, output_dir):
    # Charger l'image
    car = cv2.imread(image_path)
    # Convertir en niveau de gris
    gray = cv2.cvtColor(car, cv2.COLOR_BGR2GRAY)
    # Appliquer un flou gaussien
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    # Détecter les contours
    edged = cv2.Canny(blur, 50, 200)
    # Trouver les contours les plus grands
    cont, _ = cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cont = sorted(cont, key=cv2.contourArea, reverse=True)[:5]

    plate_cnt = None
    for c in cont:
        arc = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * arc, True)
        if len(approx) == 4:
            plate_cnt = approx
            break

    if plate_cnt is None:
        print(f"No license plate detected in {image_path}.")
        return None

    # Redresser la plaque d'immatriculation
    warped_plate = four_point_transform(gray, plate_cnt.reshape(4, 2))

    # Redimensionner la plaque pour améliorer la précision de l'OCR
    plate = cv2.resize(warped_plate, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    # Utiliser EasyOCR pour reconnaître les caractères de la plaque
    reader = Reader(['en'])
    detection = reader.readtext(plate)

    if len(detection) == 0:
        print(f"Unable to read license plate text in {image_path}.")
        return None

    # Extraire le texte reconnu
    text = detection[0][1]

    # Filtrer pour obtenir uniquement les lettres et les chiffres
    filtered_text = ''.join([c for c in text if c.isalnum()])

    # Nommer l'image avec le numéro de plaque d'immatriculation
    output_filename = os.path.join(output_dir, f'{filtered_text}.jpg')

    # Sauvegarder l'image annotée
    cv2.imwrite(output_filename, car)

    return output_filename

# Répertoire contenant les images de voitures
data_test_dir = "data_test"

# Créer un répertoire pour les images annotées
data_mat_test_dir = "data_mat_test"
os.makedirs(data_mat_test_dir, exist_ok=True)

# Parcourir les images dans le dossier data_test
for filename in os.listdir(data_test_dir):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(data_test_dir, filename)
        output_filename = process_single_image(image_path, data_mat_test_dir)
        if output_filename:
            print(f"Processed: {filename} -> Saved as: {output_filename}")
        else:
            print(f"Processed: {filename} -> No license plate detected or unable to read text.")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\0003c35a2b8bc9302c1dfaf92bc2b44c0227e16a.jpg.
# Processed: 0003c35a2b8bc9302c1dfaf92bc2b44c0227e16a.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\0003c35a2b8bc9302c1dfaf92bc2b44c0227e16a.png.
# Processed: 0003c35a2b8bc9302c1dfaf92bc2b44c0227e16a.png -> No license plate detected or unable to read text.
# No license plate detected in data_test\004cb91c234cab5ccf973b034251401fd88e8069.jpg.
# Processed: 004cb91c234cab5ccf973b034251401fd88e8069.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test
jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 3f7c9f969a137812533cfdc16e99a0aa33172fd8.png -> Saved as: data_mat_test\2334AX0U.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\3f9f6b4d08020eec964a7d3e06dc2c0b9f95953a.jpg.
# Processed: 3f9f6b4d08020eec964a7d3e06dc2c0b9f95953a.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 3fae42cc18d473f85ed2849add26548b5b26cc9f.jpg -> Saved as: data_mat_test\6361AA03.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 3fe47ef010bd71c981717757a807a65fbfa1545f.jpg -> Saved as: data_mat_test\5baxO0.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 3fe47ef010bd71c981717757a807a65fbfa1545f.png -> Saved as: data_mat_test\5baxO0.jpg
# No license plate detected in data_test\3ff7de840023d2f9a63278504df540ce9059f0b5.jpg.
# Processed: 3ff7de840023d2f9a63278504df540ce9059f0b5.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_test\3ff7de840023d2f9a63278504df540ce9059f0b5.png.
# Processed: 3ff7de840023d2f9a63278504df540ce9059f0b5.png -> No license plate detected or unable to read text.
# No license plate detected in data_test\4a055d0954a838936bb63e5ada13f353af695dd8.jpg.
# Processed: 4a055d0954a838936bb63e5ada13f353af695dd8.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4a08b5663d12bdad1fb56dd409671aca24b10e12.jpg -> Saved as: data_mat_test\0360AS00.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\4a268704d63c72089fab7aa965b66bd41f4ed8e4.jpg.
# Processed: 4a268704d63c72089fab7aa965b66bd41f4ed8e4.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4a970f6e27536ee975738556881070511b1f965d.jpg -> Saved as: data_mat_test\5220AA03.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4a970f6e27536ee975738556881070511b1f965d.png -> Saved as: data_mat_test\5220AA03.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4b3cf2e251acdb8c367e0f215e00c86aeb77e47d.jpg -> Saved as: data_mat_test\8.jpg
# No license plate detected in data_test\4b59bb51bd9c3f21f621a168950a758cbeb4ce9d.jpg.
# Processed: 4b59bb51bd9c3f21f621a168950a758cbeb4ce9d.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_test\4b7ddff7836a2d4c11da3d1361689c9ee7c4a78e.jpg.
# Processed: 4b7ddff7836a2d4c11da3d1361689c9ee7c4a78e.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4b90290ef369afbc5ec28f02f9d7f6805a58f586.jpg -> Saved as: data_mat_test\MhPM.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4c3a6fe3f965a638a4f8734c3cd25384e258bc42.jpg -> Saved as: data_mat_test\5006AR00.jpg
# No license plate detected in data_test\4c67fa47f2aeeb0ad6de71bd3549a4f0ebb519bf.jpg.
# Processed: 4c67fa47f2aeeb0ad6de71bd3549a4f0ebb519bf.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4d332db263af69285cb127ae6d30deb82567c456.jpg -> Saved as: data_mat_test\LIPSZ.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4d332db263af69285cb127ae6d30deb82567c456.png -> Saved as: data_mat_test\LIPSZ.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\4d58d7ebeccbdd0187c199e47eea0b5ca9bcef39.jpg.
# Processed: 4d58d7ebeccbdd0187c199e47eea0b5ca9bcef39.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4d7aefcc0198d128a3e303669de55977e6da9470.jpg -> Saved as: data_mat_test\1604ABO6.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4d7aefcc0198d128a3e303669de55977e6da9470.png -> Saved as: data_mat_test\1604ABO6.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 4d9628e72b3fe485c0777d1a18fd5aac0d1aa450.jpg -> Saved as: data_mat_test\.jpg
# No license plate detected in data_test\4da897ea10dddc066890cfac53ae354298cd7ba6.jpg.
# Processed: 4da897ea10dddc066890cfac53ae354298cd7ba6.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_test
jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\7b63251011cfe72ed8611ecc34deaeddba400007.jpg.
# Processed: 7b63251011cfe72ed8611ecc34deaeddba400007.jpg -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\7b63251011cfe72ed8611ecc34deaeddba400007.png.
# Processed: 7b63251011cfe72ed8611ecc34deaeddba400007.png -> No license plate detected or unable to read text.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Processed: 7b6a8ca66b47a243e4f5fd763c0662b0306b604e.jpg -> Saved as: data_mat_test\421laco6.jpg
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Unable to read license plate text in data_test\7b856a3d8e0bbe593517f9409c615aba45431a7b.jpg.
# Processed: 7b856a3d8e0bbe593517f9409c615aba45431a7b.jpg -> No license plate detected or unable to read text.
# No license plate detected in data_test\7b8efbcde09cd11e41b609caf43807ef63c86bde.jpg.
# Processed: 7b8efbcde09cd11e41b609caf43807ef63c86bde.jpg -> No license plate detected or unable to read text.
# Processed: 7bf7fdc84f9cb3b5d9c2406350b6d4d9683cb357.jpg -> Saved as: data_mat_test\56203303.jpg

# %% [markdown]
# # LE MODEL

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## Fonction pour charger les images et leurs labels

# %%
import os
import cv2
import numpy as np

# Charger les données et les étiquettes
def load_data_and_labels(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        img_path = os.path.join(data_dir, filename)
        img = cv2.imread(img_path)
        if img is not None:  # Vérifier si l'image est valide
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (128, 128))  # Redimensionner les images
            images.append(img)
            # Extraire l'étiquette à partir du nom du fichier (ici, nous supposons que le numéro de plaque est le premier élément dans le nom de fichier)
            label = filename.split('_')[0]  
            labels.append(label)
    return np.array(images), np.array(labels)

# Exemple d'utilisation avec les dossiers de données
train_dir = 'data_mat_train'
test_dir = 'data_mat_test'

X_train, y_train = load_data_and_labels(train_dir)
X_test, y_test = load_data_and_labels(test_dir)

# Normaliser les images
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
import os
import cv2
import numpy as np

# Fonction pour charger les données et les étiquettes
def load_data_and_labels(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        img_path = os.path.join(data_dir, filename)
        img = cv2.imread(img_path)
        if img is not None:  # Ignorer les images vides
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (128, 128))  # Redimensionner les images
            images.append(img)
            # Extraire l'étiquette à partir du nom du fichier (numéro de plaque d'immatriculation)
            label = filename.split('.')[0]  # Enlever l'extension du fichier
            labels.append(label)
    return np.array(images), np.array(labels)

# Charger les données d'entraînement et d'évaluation
train_dir = 'data_mat_train'
test_dir = 'data_mat_test'

X_train, y_train = load_data_and_labels(train_dir)
X_test, y_test = load_data_and_labels(test_dir)

# Normaliser les images
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Créer le modèle CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')  # Sortie binaire pour la présence/absence de plaque d'immatriculation
])

# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Afficher un résumé du modèle
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_21 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_22 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_23 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_11 (Dense)            (None, 128)               3211392
#
#  dense_12 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 3304769 (12.61 MB)
# Trainable params: 3304769 (12.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Fonction pour charger les données et les étiquettes
def load_data_and_labels(data_dir):
    images = []
    labels = []
    for filename in os.listdir(data_dir):
        img_path = os.path.join(data_dir, filename)
        img = cv2.imread(img_path)
        if img is not None:  # Ignorer les images vides
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (128, 128))  # Redimensionner les images
            images.append(img)
            # Extraire l'étiquette à partir du nom du fichier (numéro de plaque d'immatriculation)
            label = filename.split('.')[0]  # Enlever l'extension du fichier
            labels.append(label)
    return np.array(images), np.array(labels)

# Charger les données d'entraînement et de test
train_dir = 'data_mat_train'
test_dir = 'data_mat_test'

X_train, y_train = load_data_and_labels(train_dir)
X_test, y_test = load_data_and_labels(test_dir)

# Normaliser les images
X_train = X_train / 255.0
X_test = X_test / 255.0

# Encodage des étiquettes d'entraînement
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# Création d'un dictionnaire des étiquettes d'entraînement
train_labels_set = set(y_train)

# Filtrer les données de test pour inclure uniquement les étiquettes présentes dans les données d'entraînement
filtered_indices = [i for i, label in enumerate(y_test) if label in train_labels_set]
X_test_filtered = X_test[filtered_indices]
y_test_filtered = y_test[filtered_indices]

# Encoder les étiquettes de test filtrées
y_test_encoded = label_encoder.transform(y_test_filtered)

# Conversion des étiquettes en one-hot encoding
num_classes = len(np.unique(y_train_encoded))
y_train_one_hot = to_categorical(y_train_encoded, num_classes)
y_test_one_hot = to_categorical(y_test_encoded, num_classes)

# Création du modèle
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compilation du modèle
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Entraîner le modèle
history = model.fit(X_train, y_train_one_hot, epochs=10, validation_split=0.2)

# Évaluer le modèle sur les données de test filtrées
loss, accuracy = model.evaluate(X_test_filtered, y_test_one_hot)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 39/39 [==============================] - 18s 451ms/step - loss: 7.3707 - accuracy: 0.0000e+00 - val_loss: 7.3597 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 39/39 [==============================] - 16s 419ms/step - loss: 7.3250 - accuracy: 0.0032 - val_loss: 7.4383 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 39/39 [==============================] - 16s 411ms/step - loss: 7.1885 - accuracy: 0.0097 - val_loss: 7.8874 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 39/39 [==============================] - 17s 450ms/step - loss: 6.3790 - accuracy: 0.0737 - val_loss: 10.6515 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 39/39 [==============================] - 16s 418ms/step - loss: 2.9805 - accuracy: 0.4870 - val_loss: 21.3855 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 39/39 [==============================] - 16s 412ms/step - loss: 0.6560 - accuracy: 0.9076 - val_loss: 24.9624 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 39/39 [==============================] - 17s 426ms/step - loss: 0.3256 - accuracy: 0.9724 - val_loss: 23.6168 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 39/39 [==============================] - 16s 413ms/step - loss: 0.1621 - accuracy: 0.9846 - val_loss: 21.5379 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 39/39 [==============================] - 16s 415ms/step - loss: 0.0995 - accuracy: 0.9887 - val_loss: 23.5201 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 39/39 [==============================] - 16s 423ms/step - loss: 0.0628 - accuracy: 0.9903 - val_loss: 23.5739 - val_accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 75ms/step - loss: 10.1112 - accuracy: 0.1111
# Loss: 10.111178398132324, Accuracy: 0.1111111119389534

# %% [markdown]
# # tester une immage

# %%
import cv2
import numpy as np

# Charger votre image
image_path = 'DataChallenge.jpg'
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Assurez-vous que l'image est en format RGB
image = cv2.resize(image, (128, 128))  # Redimensionnez l'image à la taille d'entrée du modèle

# Normaliser l'image
image = image / 255.0

# Faire une prédiction
prediction = model.predict(np.expand_dims(image, axis=0))

# Convertir les probabilités en étiquettes
predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

print(f'Predicted label: {predicted_label}')
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Predicted label: ['72LLABOZ']

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from easyocr import Reader
import os

def order_points(pts):
    rect = np.zeros((4, 2), dtype="float32")
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]
    rect[2] = pts[np.argmax(s)]

    diff = np.diff(pts, axis=1)
    rect[1] = pts[np.argmin(diff)]
    rect[3] = pts[np.argmax(diff)]

    return rect

def four_point_transform(image, pts):
    rect = order_points(pts)
    (tl, tr, br, bl) = rect

    # Calculer les largeurs et hauteurs des côtés du rectangle
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    # Destination points for perspective transform
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    # Compute the perspective transform matrix and apply it
    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return warped

def process_single_image(image_path, output_path):
    reader = Reader(['en'], gpu=False, verbose=False)
    
    car = cv2.imread(image_path)
    car = cv2.resize(car, (800, 600))
    gray = cv2.cvtColor(car, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    edged = cv2.Canny(blur, 50, 200)
    cont, _ = cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cont = sorted(cont, key=cv2.contourArea, reverse=True)[:5]

    plate_cnt = None
    for c in cont:
        arc = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * arc, True)
        if len(approx) == 4:
            plate_cnt = approx
            break

    if plate_cnt is None:
        print("No license plate detected.")
        return

    # Redresser la plaque d'immatriculation
    warped_plate = four_point_transform(gray, plate_cnt.reshape(4, 2))

    # Redimensionner la plaque pour améliorer la précision de l'OCR
    plate = cv2.resize(warped_plate, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    # Appliquer une égalisation de l'histogramme pour améliorer le contraste
    plate = cv2.equalizeHist(plate)

    # Filtrage morphologique pour améliorer les contours des caractères
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    plate = cv2.morphologyEx(plate, cv2.MORPH_CLOSE, kernel)

    # Utiliser EasyOCR pour reconnaître les caractères
    detection = reader.readtext(plate)
    print(detection)

    if len(detection) == 0:
        text = "Impossible de lire le texte de la plaque d'immatriculation"
        cv2.putText(car, text, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 255), 3)
    else:
        # Extraire le texte reconnu
        text = detection[0][1]
        # Filtrer pour obtenir uniquement les lettres et les chiffres
        filtered_text = ''.join([c for c in text if c.isalnum()])
        if len(filtered_text) > 8:
            filtered_text = filtered_text[:8]
        cv2.drawContours(car, [plate_cnt], -1, (0, 255, 0), 3)
        display_text = f"{filtered_text} ({detection[0][2] * 100:.2f}%)"
        cv2.putText(car, display_text, (plate_cnt[0][0][0], plate_cnt[0][0][1] - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 255, 0), 2)
        print(display_text)

    # Sauvegarder l'image annotée
    cv2.imwrite(output_path, car)
    # Sauvegarder l'image de la plaque redressée
    cv2.imwrite('warped_plate.jpg', plate)

# Tester avec une seule image
process_single_image('hamada.jpg', 'annotated_test.jpg')

# Afficher les images avec matplotlib
annotated_image = cv2.imread('annotated_test.jpg')
warped_plate = cv2.imread('warped_plate.jpg', cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(10, 8))

plt.subplot(1, 2, 1)
plt.imshow(warped_plate, cmap='gray')
plt.title('Plaque d\'immatriculation')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.title('Image avec détection')
plt.axis('off')

plt.show()
# Out:
# [([[23, 0], [541, 0], [541, 82], [23, 82]], '99 734X008', 0.13912675333704252)]
# 99734X00 (13.91%)
